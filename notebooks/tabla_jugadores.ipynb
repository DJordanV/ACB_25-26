# %%
import pandas as pd

# %%
# df = pd.DataFrame(columns=[
#     'Equipo',
#     'Dorsal',
#     'Nombre',
#     'Apellido',
#     'Posición',
#     'Altura',
#     'Fecha_Nacim',
#     'Pais_Nacim',
#     'Provincia',
#     'Nacionalidad',
#     'Licencia'
# ])

# %%
jugadores = []

while True:

    equipo = 'GIR'
    # equipo = input('Equipo: ').upper()
    dorsal = input('Dorsal: ')
    nombre = input('Nombre (sin apellido): ').title()
    apellido = input('Apellido: ').title()
    posicion = input('Posición: ').capitalize()
    altura = input('Altura en cm: ')

    dia_nacim = input('Día de nacimiento (DD): ')
    mes_nacim = input('Mes de nacimiento (MM): ')
    año_nacim = input('Año de nacimiento (AAAA): ')
    fecha_nacim = dia_nacim + '/' + mes_nacim + '/' + año_nacim
    
    pais_nacim = input('País de Nacimiento: ').upper()

    if pais_nacim in ['ESP', 'ESPAÑA']:
        provincia = input('Provincia: ').upper()
    else:
        provincia = ''

    nacionalidad = input('Nacionalidad: ').upper()
    licencia = input('Licencia: ').upper()

    nueva_fila = {
        'Equipo': equipo,
        'Dorsal': dorsal,
        'Nombre': nombre,
        'Apellido': apellido,
        'Posición': posicion,
        'Altura': altura,
        'Fecha_Nacim': fecha_nacim,
        'Pais_Nacim': pais_nacim,
        'Provincia': provincia,
        'Nacionalidad': nacionalidad,
        'Licencia': licencia
    }

    jugadores.append(nueva_fila)

    continuar = input('Añadir otro jugador? (S/N): ').upper()
    if continuar != 'S':
        break

df = pd.concat(
    [df, pd.DataFrame(jugadores)],
    ignore_index=True
)

# %%
iso_paises = {
    'ESPAÑA': 'ESP',
    'ARGENTINA': 'ARG',
    'ITALIA': 'ITA',
    'CHEQUIA': 'CZE',
    'SENEGAL': 'SEN',
    'FRANCIA': 'FRA',
    'GEORGIA': 'GEO',
    'MALI': 'MLI',
    'ESTONIA': 'EST',
    'PAISES BAJOS': 'NLD',
    'SERBIA': 'SRB',
    'CROACIA': 'HRV',
    'HUNGRIA': 'HUN',
    'MONTENEGRO': 'MNE',
    'REINO UNIDO': 'GBR',
    'LITUANIA': 'LTU'
}
df.replace(iso_paises, inplace=True)

# %%
df
# Out:
#    Equipo Dorsal      Nombre      Apellido   Posición Altura Fecha_Nacim  \
# 0     BAR      0       Kevin        Punter    Escolta    193  25/06/1993
# 1     BAR      2       Juani        Marcos       Base    190  06/07/2000
# 2     BAR      3       Myles          Cale      Alero    198  05/03/1999
# 3     BAR      5       Miles        Norris  Ala-pívot    206  15/04/2000
# 4     BAR      6         Jan        Vesely      Pivot    210  24/04/1990
# 5     BAR      8       Darío      Brizuela    Escolta    188  08/11/1994
# 6     BAR     13       Tomas    Satoransky       Base    201  30/10/1991
# 7     BAR     14       Willy   Hernangómez      Pivot    210  27/05/1994
# 8     BAR     17        Juan         Núñez       Base    191  04/06/2004
# 9     BAR     19  Youssoupha          Fall      Pivot    221  12/01/1995
# 10    BAR     20        Nico  Laprovittola       Base    190  31/01/1990
# 11    BAR     21        Will       Clyburn      Alero    201  17/05/1990
# 12    BAR     23     Tornike     Shengelia  Ala-pivot    206  05/10/1991
# 13    BAR     41       Sayon         Keita      Pivot    212  01/03/2008
# 14    BAR     43      Nikola     Kusturica      Alero    203  30/04/2009
# 15    BAR     44        Joel         Parra      Alero    202  04/04/2000
# 16    BAR     47        Dani      González    Escolta    190  28/02/2007
# 17    JOV      0       Henri         Drell  Ala-pivot    206  25/04/2000
# 18    JOV      1     Yannick         Kraag      Alero    202  16/10/2002
# 19    JOV      9       Ricky         Rubio       Base    189  21/10/1990
# 20    JOV     11      Jabari        Parker  Ala-pivot    203  15/03/1995
# 21    JOV     12       Ludde      Hakanson       Base    189  22/03/1996
# 22    JOV     16     Guillem         Vives       Base    192  16/06/1993
# 23    JOV     20      Adrián        Torres      Alero    203  12/09/2006
# 24    JOV     21      Miguel         Allen      Alero    205  10/05/2003
# 25    JOV     22    Humberto          Ruiz    Escolta    198  07/02/2009
# 26    JOV     23     Michael         Ruzic  Ala-pivot    206  04/10/2006
# 27    JOV     24     Cameron          Hunt    Escolta    191  25/08/1997
# 28    JOV     25      Yannis         Morin      Pivot    208  31/08/1993
# 29    JOV     32      Ferran         Mauri       Base    191  30/09/2007
# 30    JOV     34       Diego        Niebla    Escolta    202  18/01/2008
# 31    JOV     35       Simon     Birgander      Pivot    209  23/10/1997
# 32    JOV     44        Ante         Tomic      Pivot    217  17/02/1987
# 33    JOV     88        Adam         Hanga      Alero    201  12/04/1989
# 34    GIR      2        Maxi     Fjellerup    Escolta    198  25/11/1997
# 35    GIR      4         Pep      Busquets    Escolta    201  02/03/1999
# 36    GIR      5       Derek       Needham       Base    180  20/10/1990
# 37    GIR      6     Cameron      Hildreth      Alero    195  18/09/2002
# 38    GIR      8        Mark        Hughes    Escolta    199  15/02/1997
# 39    GIR      9     Guillem      Ferrando       Base    184   08/01/200
# 40    GIR     10        Pepe       Vildoza       Base    190  15/01/1996
# 41    GIR     11        Otis    Livingston       Base    181  12/10/1996
# 42    GIR     12    Martinas         Geben      Pivot    208  20/10/1994
# 43    GIR     13       James        Karnik      Pivot    206  17/07/1998
# 44    GIR     16        Izan         Soler      Pivot    197  18/03/2006
# 45    GIR     17       Enric     Sanmartín    Escolta    199  11/01/2007
# 46    GIR     20       Khory        Brunot      Alero    198  20/08/2006
# 47    GIR     21        Juan     Fernández      Pivot    210  21/11/2002
# 48    GIR     23       Sergi      Martínez      Alero    202  10/05/1999
# 49    GIR     25      Nikola         Maric  Ala-pivot    206  19/12/1998
# 50    GIR     29   Mindaugas     Susinskas      Alero    204  22/02/1995
#
#    Pais_Nacim Provincia Nacionalidad Licencia
# 0         USA                    SRB      EUR
# 1         ARG                    ITA      EUR
# 2         USA                    USA      EXT
# 3         USA                    USA      EXT
# 4         CZE                    CZE      EUR
# 5         ESP       EUS          ESP      JFL
# 6         CZE                    CZE      EUR
# 7         ESP       MAD          ESP      JFL
# 8         ESP       MAD          ESP      JFL
# 9         SEN                    FRA      EUR
# 10        ARG                    ITA      EUR
# 11        USA                    USA      EXT
# 12        GEO                    GEO      JFL
# 13        MLI                    MLI      JFL
# 14        SRB                    SRB      EUR
# 15        ESP       CAT          ESP      JFL
# 16        ESP       CYL          ESP      JFL
# 17        EST                    EST      EUR
# 18        NLD                    NLD      JFL
# 19        ESP       CAT          ESP      JFL
# 20        USA                    USA      EXT
# 21        SWE                    SWE      JFL
# 22        ESP       CAT          ESP      JFL
# 23        ESP       CAT          ESP      JFL
# 24        ESP       CAN          ESP      JFL
# 25        ESP       CAT          ESP      JFL
# 26        FRA                    HRV      EUR
# 27        USA                    USA      EXT
# 28        FRA                    FRA      EUR
# 29        ESP       CAT          ESP      JFL
# 30        ESP       GAL          ESP      JFL
# 31        SWE                    SWE      EUR
# 32        HRV                    HRV      EUR
# 33        HUN                    HUN      EUR
# 34        ARG                    ARG      EUR
# 35        ESP       CAT          ESP      JFL
# 36        USA                    MNE      EUR
# 37        GBR                    GBR      EUR
# 38        USA                    USA      EXT
# 39        ESP       VAL          ESP      JFL
# 40        ARG                    ITA      EUR
# 41        USA                    USA      EXT
# 42        LTU                    LTU      EUR
# 43        CAN                    CZE      EUR
# 44        ESP       CAT          ESP      JFL
# 45        ESP       CAT          ESP      JFL
# 46        FRA                    FRA      EUR
# 47        ARG                    ESP      JFL
# 48        ESP       CAT          ESP      JFL
# 49        BIH                    BIH      JFL
# 50        LTU                    LTU      EUR

# %%
# df.loc[26, 'Pais_Nacim'] = 'FRANCIA'

# %%
# df = df.drop(11)
